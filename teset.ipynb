# %%
# FILEPATH: your_notebook.ipynb

def execute_query(query):
    # BEGIN: Connection details
    db_config = {
        'host': 'localhost',
        'user': 'your_username',
        'password': 'your_password',
        'database': 'your_database'
    }
    # END: Connection details
    
    import mysql.connector
    
    connection = mysql.connector.connect(**db_config)
    cursor = connection.cursor()
    
    try:
        cursor.execute(query)
        if query.strip().upper().startswith("SELECT"):
            results = cursor.fetchall()
            return results
        else:
            connection.commit()
            return cursor.rowcount
    finally:
        cursor.close()
        connection.close()

def execute_query_with_config(query, db_config):
    import mysql.connector
    
    connection = mysql.connector.connect(**db_config)
    cursor = connection.cursor()
    
    try:
        cursor.execute(query)
        if query.strip().upper().startswith("SELECT"):
            results = cursor.fetchall()
            return results
        else:
            connection.commit()
            return cursor.rowcount
    finally:
        cursor.close()
        connection.close()

# Test the functions
select_query = "SELECT * FROM your_table;"
insert_query = "INSERT INTO your_table (column1, column2) VALUES (value1, value2);"

# Test the first function
select_results = execute_query(select_query)
insert_results = execute_query(insert_query)

# Test the second function
db_config = {
    'host': 'localhost',
    'user': 'your_username',
    'password': 'your_password',
    'database': 'your_database'
}
select_results_with_config = execute_query_with_config(select_query, db_config)
insert_results_with_config = execute_query_with_config(insert_query, db_config)
# FILEPATH: your_notebook.ipynb

# BEGIN: Use existing connection
select_results_with_config = execute_query_with_config(select_query, {
    'host': '145.14.151.151',
    'port': 3306,
    'user': 'u492297623_stud1',
    'password': ,
    'database': 'u492297623_student1'
})
# END: Use existing connection
# Out:
#   Cell In[1], line 72
#     'password': ,
#               ^
# SyntaxError: expression expected after dictionary key and ':'
